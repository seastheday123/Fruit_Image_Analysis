# %% [markdown]
# Gradiant Boosting Analysis for MDS, TSNE, and PCA Scalling

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
#Read in MDS scaled data
MDS = pd.read_csv('fruit_data_MDS_3D.csv', encoding='utf-8', header =0)
MDS_test = pd.read_csv('fruit_data_MDS_Test.csv', encoding='utf-8', header =0)

#Read in TSNE scaled data
TSNE = pd.read_csv('fruit_data_TSNE_3D.csv', encoding='utf-8', header =0)
TSNE_test = pd.read_csv('fruit_data_TSNE_Test.csv', encoding='utf-8', header =0)

#Read in PCA scaled data
PCA = pd.read_csv('fruit_data_PCA_3D.csv', encoding='utf-8', header =0)
PCA_test = pd.read_csv('fruit_data_PCA_Test.csv', encoding='utf-8', header =0)

PCA
# Out:
#          num  Number           Fruit          x           y           z
# 0          0       0  Apple Braeburn  30.890803  -49.656090  -80.268097
# 1          1       0  Apple Braeburn -54.008599   27.394160  -34.873943
# 2          2       0  Apple Braeburn -54.326217   26.326451  -35.672884
# 3          3       0  Apple Braeburn -56.430016   26.971519  -36.434727
# 4          4       0  Apple Braeburn -56.971121   26.144320  -36.161755
# ...      ...     ...             ...        ...         ...         ...
# 67687  67687     130      Watermelon -48.494688   72.432683  100.067680
# 67688  67688     130      Watermelon -35.080460   77.421205  100.174408
# 67689  67689     130      Watermelon  26.055431   58.819890  -19.124888
# 67690  67690     130      Watermelon -35.924489   73.738183   99.126940
# 67691  67691     130      Watermelon  40.243010  116.354264   16.147637
#
# [67692 rows x 6 columns]

# %%
#pull out the target values
MDS_target = MDS['Number']
MDS_test_target = MDS_test['Number']

TSNE_target = TSNE['Number']
TSNE_test_target = TSNE_test['Number']

PCA_target = PCA['Number']
PCA_test_target = PCA_test['Number']

#pull out the names of the fuit (indexing same for all scallings)
name_of_fruit = MDS['Fruit']

#Drop irrelevent columbs and save them to a new array
MDS_clean = MDS.drop(['num', 'Number', 'Fruit'], axis=1)
MDS_test_clean = MDS_test.drop(['num', 'Number', 'Fruit'], axis=1)

TSNE_clean = TSNE.drop(['num', 'Number', 'Fruit'], axis=1)
TSNE_test_clean = TSNE_test.drop(['num', 'Number', 'Fruit'], axis=1)

PCA_clean = PCA.drop(['num', 'Number', 'Fruit'], axis=1)
PCA_test_clean = PCA_test.drop(['num', 'Number', 'Fruit'], axis=1)

# %%
#Create gradiant boosting model for MDS
gb_MDS = GradientBoostingRegressor(learning_rate=0.01, n_estimators=10000)

gb_MDS.fit(MDS_clean, MDS_target)
gb_MDS_test_pred = gb_MDS.predict(MDS_test_clean)
mse_gb = mean_squared_error(gb_MDS_test_pred, MDS_test_target)
cross_val_gb = -cross_val_score(gb_MDS, MDS_clean,MDS_target, scoring='neg_mean_squared_error').mean()
print(mse_gb, cross_val_gb)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-e47ffa7bdbee> in <module>
#       5 gb_MDS_test_pred = gb_MDS.predict(MDS_test_clean)
#       6 mse_gb = mean_squared_error(gb_MDS_test_pred, MDS_test_target)
# ----> 7 cross_val_gb = -cross_val_score(gb_MDS, MDS_clean,MDS_target, scoring='neg_mean_squared_error').mean()
#       8 print(mse_gb, cross_val_gb)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
# ...

# %%
#Create gradiant boosting model for TSNE
gb_TSNE = GradientBoostingRegressor(learning_rate=0.01, n_estimators=10000)

gb_TSNE.fit(TSNE_clean, TSNE_target)
gb_TSNE_test_pred = gb_TSNE.predict(TSNE_test_clean)
mse_gb = mean_squared_error(gb_TSNE_test_pred, TSNE_test_target)
cross_val_gb = -cross_val_score(gb_TSNE, TSNE_clean, TSNE_target, scoring='neg_mean_squared_error').mean()
print(mse_gb, cross_val_gb)

# %%
#Create gradiant boosting model for PCA
gb_PCA = GradientBoostingRegressor(learning_rate=0.01, n_estimators=10000)

gb_PCA.fit(PCA_clean, PCA_target)
gb_PCA_test_pred = gb_PCA.predict(PCA_test_clean)
mse_gb = mean_squared_error(gb_PCA_test_pred, PCA_test_target)
cross_val_gb = -cross_val_score(gb_PCA, PCA_clean, PCA_target, scoring='neg_mean_squared_error').mean()
print(mse_gb, cross_val_gb)
